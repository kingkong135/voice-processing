# %%
# for read/ write wav files
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # the sample rate (samples/sec) as well as the raw data samples as numeric value frames

# %%
y, sr = librosa.load('data/one.wav')

# %%
sr
# Out:
# 22050

# %%
# Calculate 
len(y) / sr
# Out:
# 2.9440362811791383

# %%
# write file
librosa.output.write_wav('new_test.wav', y, sr)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
y
# Out:
# array([ 6.4160777e-12,  1.3676048e-11, -3.3840507e-11, ...,
#         4.4742560e-06, -9.0348061e-05,  0.0000000e+00], dtype=float32)

# %%
plt.plot(y)

# %%
# plot by time
x = np.arange(len(y)) / sr
plt.plot(x, y)

# %%
tmin, tmax = 0.450, 0.475
imin, imax = int(tmin*sr), int(tmax*sr)
plt.plot(x[imin:imax], y[imin:imax])
